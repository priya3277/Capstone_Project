# %%
# Import pandas library 
import pandas as pd 
  
# initialize list of lists
data = {'Postal code':['M5H', 'M2H', 'M4B', 'M1J','M4G','M4M','M1R', 'M9V','M9L','M5V','M1B','M5A'], 'Borough':['Downtown Toronto', 'North york', 'East york', 'Scarborough', 'East Toronto', 'Etpbicoke','North york','East york','Downtown Toronto','Scarborough','Downtown Toronto','North york']
       ,'Neighborhood':['Central Bay street','Hill crest village','Parkview Hill','Scarborough village','Leaside','Studio district','wexford','South steelless','Humber suumit','CN Tower King','Malvern','Regenrt Park']} 
  
# Create DataFrame 
df = pd.DataFrame(data) 
  
# Print the output. 
df
# Out:
#    Postal code           Borough         Neighborhood
# 0          M5H  Downtown Toronto   Central Bay street
# 1          M2H        North york   Hill crest village
# 2          M4B         East york        Parkview Hill
# 3          M1J       Scarborough  Scarborough village
# 4          M4G      East Toronto              Leaside
# 5          M4M         Etpbicoke      Studio district
# 6          M1R        North york              wexford
# 7          M9V         East york      South steelless
# 8          M9L  Downtown Toronto        Humber suumit
# 9          M5V       Scarborough        CN Tower King
# 10         M1B  Downtown Toronto              Malvern
# 11         M5A        North york         Regenrt Park

# %%
# Import pandas library 
import pandas as pd 
  
# initialize list of lists
data = {'Postal code':['M5H', 'M2H', 'M4B', 'M1J','M4G','M4M','M1R', 'M9V','M9L','M5V','M1B','M5A'], 'Borough':['Downtown Toronto', 'North york', 'East york', 'Scarborough', 'East Toronto', 'Etpbicoke','North york','East york','Downtown Toronto','Scarborough','Downtown Toronto','North york']
       ,'Neighborhood':['Central Bay street','Hill crest village','Parkview Hill','Scarborough village','Leaside','Studio district','wexford','South steelless','Humber suumit','CN Tower King','Malvern','Regenrt Park'],
       'Latitude':[43.657,43.8037,43.7063,43.8768,43.9876,43.6536,43.2787,43.71261,43.3679,43.7246,43.2345,43.67326],'Longitude':[-79.38756,-79.2487,-79.7542,-79.3663,-79.6754,-79.6878,-79.4572,-79.6354,-79.7524,-79.76624,-79.8254,-79.2766]} 
  
# Create DataFrame 
df = pd.DataFrame(data) 
  
# Print the output. 
df
# Out:
#    Postal code           Borough         Neighborhood  Latitude  Longitude
# 0          M5H  Downtown Toronto   Central Bay street  43.65700  -79.38756
# 1          M2H        North york   Hill crest village  43.80370  -79.24870
# 2          M4B         East york        Parkview Hill  43.70630  -79.75420
# 3          M1J       Scarborough  Scarborough village  43.87680  -79.36630
# 4          M4G      East Toronto              Leaside  43.98760  -79.67540
# 5          M4M         Etpbicoke      Studio district  43.65360  -79.68780
# 6          M1R        North york              wexford  43.27870  -79.45720
# 7          M9V         East york      South steelless  43.71261  -79.63540
# 8          M9L  Downtown Toronto        Humber suumit  43.36790  -79.75240
# 9          M5V       Scarborough        CN Tower King  43.72460  -79.76624
# 10         M1B  Downtown Toronto              Malvern  43.23450  -79.82540
# ...
